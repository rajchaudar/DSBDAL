# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("Features in the dataset and their types:")
print(df.dtypes)
# Out:
# Features in the dataset and their types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Distribution of sepal length')  
plt.show()

# %%
sns.boxplot(df)
plt.title("Box Plot for All Features")
plt.show()

# %%
def detect_outliers(data, feature):
    Q1 = data[feature].quantile(0.25)
    Q3 = data[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[feature] < lower_bound) | (data[feature] > upper_bound)]
    return outliers

print("Outlier detection for each feature:")
for feature in df.columns[:-1]:  
    outliers = detect_outliers(df, feature)
    print(f"{feature} → {len(outliers)} outliers")
# Out:
# Outlier detection for each feature:
# sepal_length → 0 outliers
# sepal_width → 4 outliers
# petal_length → 0 outliers
# petal_width → 0 outliers

# %%
df.hist()
plt.suptitle("Feature Distributions - Histograms")
plt.show()
